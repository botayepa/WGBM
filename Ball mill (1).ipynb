# %%
import pandas as pd
import numpy as np

# %%
pip install pandas openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df = pd.read_excel(r"C:\Users\botay\OneDrive\Desktop\Ball mill.xlsx", engine='openpyxl')

# Save as CSV
df.to_csv("output_file.csv", index=False)

# %%
df1 = pd.read_csv("output_file.csv")

# %%
df.head()
# Out:
#         Date Shift  RH  Oxide   Crushed odisha  NMDC  Odisha  VALE BRBF  \
# 0 2025-04-01     C  34       0               0     0       0         58
# 1        NaT     A  34       0               0     0       0         58
# 2        NaT     B  34       0               0     0       0         58
# 3 2025-04-02     C  34       0               0     0       0         58
# 4        NaT     A  34       0               0     0       0         58
#
#    Vale IOCJ  MEL  Total  Feed (TPH)  Feed water  Cyclone Pressure
# 0          0    8    100         630         0.6              0.70
# 1          0    8    100         630         0.6              0.65
# 2          0    8    100         630         0.6              0.62
# 3          0    8    100         630         0.6              0.62
# 4          0    8    100         670         0.6              0.62

# %%
df1.head()
# Out:
#          Date Shift  RH  Oxide   Crushed odisha  NMDC  Odisha  VALE BRBF  \
# 0  2025-04-01     C  34       0               0     0       0         58
# 1         NaN     A  34       0               0     0       0         58
# 2         NaN     B  34       0               0     0       0         58
# 3  2025-04-02     C  34       0               0     0       0         58
# 4         NaN     A  34       0               0     0       0         58
#
#    Vale IOCJ  MEL  Total  Feed (TPH)  Feed water  Cyclone Pressure
# 0          0    8    100         630         0.6              0.70
# 1          0    8    100         630         0.6              0.65
# 2          0    8    100         630         0.6              0.62
# 3          0    8    100         630         0.6              0.62
# 4          0    8    100         670         0.6              0.62

# %%
df1.fillna(0, inplace=True)

# %%
df1.head()
# Out:
#          Date Shift  RH  Oxide   Crushed odisha  NMDC  Odisha  VALE BRBF  \
# 0  2025-04-01     C  34       0               0     0       0         58
# 1           0     A  34       0               0     0       0         58
# 2           0     B  34       0               0     0       0         58
# 3  2025-04-02     C  34       0               0     0       0         58
# 4           0     A  34       0               0     0       0         58
#
#    Vale IOCJ  MEL  Total  Feed (TPH)  Feed water  Cyclone Pressure
# 0          0    8    100         630         0.6              0.70
# 1          0    8    100         630         0.6              0.65
# 2          0    8    100         630         0.6              0.62
# 3          0    8    100         630         0.6              0.62
# 4          0    8    100         670         0.6              0.62

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1041 entries, 0 to 1040
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              1041 non-null   object
#  1   Shift             1041 non-null   object
#  2   RH                1041 non-null   int64
#  3   Oxide             1041 non-null   int64
#  4   Crushed odisha    1041 non-null   int64
#  5   NMDC              1041 non-null   int64
#  6   Odisha            1041 non-null   int64
#  7   VALE BRBF         1041 non-null   int64
#  8   Vale IOCJ         1041 non-null   int64
#  9   MEL               1041 non-null   int64
#  10  Total             1041 non-null   int64
#  11  Feed (TPH)        1041 non-null   int64
#  12  Feed water        1041 non-null   float64
#  13  Cyclone Pressure  1041 non-null   float64
# dtypes: float64(2), int64(10), object(2)
# memory usage: 114.0+ KB

# %%
df1.isnull().sum()
# Out:
# Date                0
# Shift               0
# RH                  0
# Oxide               0
# Crushed odisha      0
# NMDC                0
# Odisha              0
# VALE BRBF           0
# Vale IOCJ           0
# MEL                 0
# Total               0
# Feed (TPH)          0
# Feed water          0
# Cyclone Pressure    0
# dtype: int64

# %%
Y=df1[["Feed (TPH)", "Feed water",	"Cyclone Pressure"]]

# %%
X = df1[["RH","Oxide ", "Crushed odisha", "NMDC", "Odisha", "VALE BRBF", "Vale IOCJ",  "MEL"]]

# %%
X.head()
# Out:
#    RH  Oxide   Crushed odisha  NMDC  Odisha  VALE BRBF  Vale IOCJ  MEL
# 0  34       0               0     0       0         58          0    8
# 1  34       0               0     0       0         58          0    8
# 2  34       0               0     0       0         58          0    8
# 3  34       0               0     0       0         58          0    8
# 4  34       0               0     0       0         58          0    8

# %%
Y.head()
# Out:
#    Feed (TPH)  Feed water  Cyclone Pressure
# 0         630         0.6              0.70
# 1         630         0.6              0.65
# 2         630         0.6              0.62
# 3         630         0.6              0.62
# 4         670         0.6              0.62

# %%
print(df1.dtypes)
# Out:
# Date                 object
# Shift                object
# RH                    int64
# Oxide                 int64
# Crushed odisha        int64
# NMDC                  int64
# Odisha                int64
# VALE BRBF             int64
# Vale IOCJ             int64
# MEL                   int64
# Total                 int64
# Feed (TPH)            int64
# Feed water          float64
# Cyclone Pressure    float64
# dtype: object

# %%
print(X.shape,Y.shape)
# Out:
# (1041, 8) (1041, 3)

# %%
# # Step 1: Replace non-breaking spaces with regular spaces
# df1.replace(u'\xa0', '', regex=True, inplace=True)

# # Step 2: Convert all columns to numeric where possible
# df1 = df1.apply(pd.to_numeric, errors='coerce')

# # Step 3: Replace any resulting NaNs with 0
# df1.fillna(0, inplace=True)

# %%
# df1 = df1.applymap(lambda x: str(x).replace('\xa0', '').strip() if isinstance(x, str) else x)

# # Step 2: Convert all columns to numeric where possible
# df1 = df1.apply(pd.to_numeric, errors='coerce')

# # Step 3: Replace any NaNs with 0
# df1.fillna(0, inplace=True)

# %%
# import re

# # Step 1: Force all object columns to clean numeric strings
# def clean_cell(cell):
#     if isinstance(cell, str):
#         # Remove non-breaking spaces, text, units, commas, symbols
#         cleaned = re.sub(r'[^\d.\-]', '', cell)
#         return cleaned.strip()
#     return cell

# df2 = df1.applymap(clean_cell)

# # Step 2: Convert all columns to numeric, force errors to NaN
# df2 = df1.apply(pd.to_numeric, errors='coerce')

# # Step 3: Fill all NaNs with 0
# df2.fillna(0, inplace=True)

# # Step 4: Check if cleaning worked
# print(df.dtypes)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y, test_size=0.2,random_state=2)

# %%
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
Y_pred = model.predict(X_test)

# %%
print(Y_pred)
# Out:
# [[6.33759429e+02 6.00000000e-01 6.26915564e-01]
#  [6.56860009e+02 5.91276571e-01 6.32324001e-01]
#  [7.67930947e+02 7.12782284e-01 6.98063015e-01]
#  [7.39305328e+02 5.72578604e-01 6.51722482e-01]
#  [7.51369090e+02 9.06955540e-01 7.09122415e-01]
#  [7.74069412e+02 6.65405654e-01 6.99177843e-01]
#  [7.54726168e+02 6.21657038e-01 7.01567778e-01]
#  [7.39305328e+02 5.72578604e-01 6.51722482e-01]
#  [8.25921581e+02 6.82393359e-01 6.85857333e-01]
#  [7.58997562e+02 6.34071776e-01 6.43699370e-01]
#  [7.25531937e+02 6.23395027e-01 6.57633131e-01]
#  [6.33759429e+02 6.00000000e-01 6.26915564e-01]
#  [7.58997562e+02 6.34071776e-01 6.43699370e-01]
#  [7.60543983e+02 6.85820306e-01 6.26901606e-01]
#  [7.81320238e+02 6.39388811e-01 7.04528095e-01]
#  [8.53922429e+02 7.61658261e-01 7.00579464e-01]
#  [6.23087332e+02 4.00000000e-01 6.23670865e-01]
#  [6.96170302e+02 5.97702752e-01 6.83981413e-01]
#  [8.25921581e+02 6.82393359e-01 6.85857333e-01]
#  [6.52223491e+02 5.60976350e-01 6.89780351e-01]
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)
print(f"✅ Mean Squared Error: {mse:.2f}")
print(f"✅ R² Score: {r2:.4f}")
# Out:
# ✅ Mean Squared Error: 575.10
# ✅ R² Score: 0.6706

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Actual Feed'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import joblib
joblib.dump(model, 'ball_mill_model.pkl')
# Out:
# ['ball_mill_model.pkl']

# %%
from sklearn.multioutput import MultiOutputRegressor
from xgboost import XGBRegressor

model = MultiOutputRegressor(XGBRegressor())
model.fit(X_train, Y_train)
# Out:
# MultiOutputRegressor(estimator=XGBRegressor(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None, device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None,
#                                             feature_types=None, gamma=None,
#                                             grow_policy=None,
#                                             importance_type=None,
#                                             interaction_constraints=None,
#                                             learning_rate=None, max_bin=None,
# ...

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_pred = model.predict(X_test)
print("MSE:", mean_squared_error(Y_test, Y_pred))
print("R2:", r2_score(Y_test, Y_pred))
# Out:
# MSE: 466.1816879697531
# R2: -1.2935149766138954

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import StandardScaler

# Scaling
scaler_X = StandardScaler()
scaler_Y = StandardScaler()

X_train_scaled = scaler_X.fit_transform(X_train)
Y_train_scaled = scaler_Y.fit_transform(Y_train)

model1 = MultiOutputRegressor(MLPRegressor(hidden_layer_sizes=(100, 50), max_iter=1000, random_state=42))
model1.fit(X_train_scaled, Y_train_scaled)
# Out:
# MultiOutputRegressor(estimator=MLPRegressor(hidden_layer_sizes=(100, 50),
#                                             max_iter=1000, random_state=42))

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_pred = model1.predict(X_test)
print("MSE:", mean_squared_error(Y_test, Y_pred))
print("R2:", r2_score(Y_test, Y_pred))
# Out:
# MSE: 458.1756179224794
# R2: -35.87379047307265
# C:\Users\botay\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# C:\Users\botay\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(
# C:\Users\botay\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but MLPRegressor was fitted without feature names
#   warnings.warn(

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = df.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()
